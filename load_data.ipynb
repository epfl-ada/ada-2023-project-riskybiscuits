# %% [markdown]
# # Load data from the file
#
# This file is here to load all the data from the various datasets and generate a merged version: `data/us_users_ratings.csv`.

# %%
import pandas as pd

from data_loader import (
    get_users_df,
    get_reviews_df,
    get_beers_df,
    get_breweries_df,
    join_breweries_on_beers,
    merge_reviews,
    get_us_reviews
)

# %%
reviews_path_ba = "data/matched_beer_data/ratings_ba.txt"
reviews_path_rb = "data/matched_beer_data/ratings_rb.txt"
users_path_ba = "data/users_ba.csv"
users_path_rb = "data/users_rb.csv"
breweries_path = "data/matched_beer_data/breweries.csv"
beers_path = "data/matched_beer_data/beers.csv"

# %% [markdown]
# ## 1) Loading data
#
# - All the pre-processing is done using the functions defined in `data_loader.py`.
# - The preprocessing functions are described and documented in `data_loader.py`.
# - We use the reviews/ ratings from both BeerAdvocate and RateBeer, and use the matched beers and breweries dataset to make sure that the names of the same beers are identical across the two datasets.
# - Those two reviews/ ratings datasets are then merged and joined to the breweries, beers and users datasets to obtain a single complete dataframe of beer reviews.
# - After all the processing and merging is done, the final dataframe is saved as `data/us_users_ratings.csv` to be used in the analysis.

# %%
users_df_ba = get_users_df(users_path_ba)
users_df_rb = get_users_df(users_path_rb)
ba_df = get_reviews_df(reviews_path_ba)
rb_df = get_reviews_df(reviews_path_rb)
breweries_df = get_breweries_df(breweries_path)
beers_df = get_beers_df(beers_path)
beers_df = join_breweries_on_beers(beers_df, breweries_df)
reviews_df = merge_reviews(ba_df, rb_df, beers_df, users_df_ba, users_df_rb)
climate_classifications = pd.read_csv("data/climate_classified.csv")
climate_classifications.set_index("climate", inplace=True)
states_climate = pd.read_csv("data/states_climate.csv")
states_climate.set_index("State", inplace=True)
us_users_ratings = get_us_reviews(
    reviews_df=reviews_df, climate_classifications=climate_classifications, states_climate=states_climate
)

# save csv
us_users_ratings.to_csv("data/us_users_ratings.csv", compression="gzip", index=False)

# %% [markdown]
# The following cell displays the dataframe to ensure that the data is loaded correctly.

# %%
us_users_ratings.head()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_20004\3328987270.py:1: DtypeWarning: Columns (3,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv("data/us_users_ratings.csv", compression="gzip")
#          beer_id        date       user_name                user_id  \
# 0          19827  1417431600       Hellpop65        hellpop65.48993
# 1          19827  1401357600        Latarnik         latarnik.52897
# 2          19827  1393412400  RochefortChris  rochefortchris.697017
# 3          19827  1392030000      OKCNittany      okcnittany.144868
# 4          19827  1390647600          jaydoc          jaydoc.265507
# ...          ...         ...             ...                    ...
# 1169618   147726  1321614000              GT                  74823
# 1169619   147726  1321614000   BeerandBlues2                   9357
# 1169620   147726  1321614000         Butters                  67029
# 1169621   147726  1320318000          Travlr                  83882
# 1169622   147726  1317031200           EricE                  66556
#
#          appearance     aroma  palate     taste   overall    rating  \
# 0               NaN       NaN     NaN       NaN       NaN  3.250000
# 1               NaN       NaN     NaN       NaN       NaN  3.500000
# 2               NaN       NaN     NaN       NaN       NaN  3.500000
# 3               NaN       NaN     NaN       NaN       NaN  3.750000
# 4               NaN       NaN     NaN       NaN       NaN  3.250000
# ...             ...       ...     ...       ...       ...       ...
# 1169618         3.0  2.333333     2.0  2.333333  2.473684  2.422222
# 1169619         2.0  3.222222     2.0  2.777778  3.105263  2.866667
# 1169620         3.0  1.888889     2.0  1.888889  1.631579  1.888889
# 1169621         2.0  1.888889     2.0  2.777778  1.842105  2.066667
# 1169622         3.0  3.222222     2.0  2.777778  3.315789  3.044444
#
#                                                       text review  abv  \
# 0                                                      NaN  False  4.8
# 1                                                      NaN  False  4.8
# 2                                                      NaN  False  4.8
# 3                                                      NaN  False  4.8
# 4                                                      NaN  False  4.8
# ...                                                    ...    ...  ...
# 1169618  16oz can thanks to Travlr. Pour is wildly clea...    NaN  4.8
# 1169619  Can shared by Travlr.  Pours clear pale gold w...    NaN  4.8
# 1169620  Sampled at the DC gathering at GTâs place.  ...    NaN  4.8
# 1169621  Can.  Clear golden color, medium white head wi...    NaN  4.8
# 1169622  Yay! A Liechtenstein tick.  Can from Coop, Lau...    NaN  4.8
#
#          beer_avg_rating_ba  beer_id_ba beer_name  brewery_id_ba  \
# 0                  3.439867       19827  Legbiter          10093
# 1                  3.439867       19827  Legbiter          10093
# 2                  3.439867       19827  Legbiter          10093
# 3                  3.439867       19827  Legbiter          10093
# 4                  3.439867       19827  Legbiter          10093
# ...                     ...         ...       ...            ...
# 1169618            3.000000       78681     Krona          21278
# 1169619            3.000000       78681     Krona          21278
# 1169620            3.000000       78681     Krona          21278
# 1169621            3.000000       78681     Krona          21278
# 1169622            3.000000       78681     Krona          21278
#
#          nbr_ratings_ba             style  beer_avg_rating_rb  beer_id_rb  \
# 0                    75  English Pale Ale            2.923596       37923
# 1                    75  English Pale Ale            2.923596       37923
# 2                    75  English Pale Ale            2.923596       37923
# 3                    75  English Pale Ale            2.923596       37923
# 4                    75  English Pale Ale            2.923596       37923
# ...                 ...               ...                 ...         ...
# 1169618               2   Euro Pale Lager            2.215686      147726
# 1169619               2   Euro Pale Lager            2.215686      147726
# 1169620               2   Euro Pale Lager            2.215686      147726
# 1169621               2   Euro Pale Lager            2.215686      147726
# 1169622               2   Euro Pale Lager            2.215686      147726
#
#          brewery_id_rb  nbr_ratings_rb  beer_avg_rating_ba_rb  \
# 0                 4959              89               3.159695
# 1                 4959              89               3.159695
# 2                 4959              89               3.159695
# 3                 4959              89               3.159695
# 4                 4959              89               3.159695
# ...                ...             ...                    ...
# 1169618           9151              51               2.245283
# 1169619           9151              51               2.245283
# 1169620           9151              51               2.245283
# 1169621           9151              51               2.245283
# 1169622           9151              51               2.245283
#
#          brewery_location                          brewery_name  \
# 0        Northern Ireland  Strangford Lough Brewing Company Ltd
# 1        Northern Ireland  Strangford Lough Brewing Company Ltd
# 2        Northern Ireland  Strangford Lough Brewing Company Ltd
# 3        Northern Ireland  Strangford Lough Brewing Company Ltd
# 4        Northern Ireland  Strangford Lough Brewing Company Ltd
# ...                   ...                                   ...
# 1169618     Liechtenstein              Liechtensteiner Brauhaus
# 1169619     Liechtenstein              Liechtensteiner Brauhaus
# 1169620     Liechtenstein              Liechtensteiner Brauhaus
# 1169621     Liechtenstein              Liechtensteiner Brauhaus
# 1169622     Liechtenstein              Liechtensteiner Brauhaus
#
#          brewery_nbr_beers_ba  brewery_nbr_beers_rb   user_location  \
# 0                           5                     5          Kansas
# 1                           5                     5      New Jersey
# 2                           5                     5  North Carolina
# 3                           5                     5        Oklahoma
# 4                           5                     5          Kansas
# ...                       ...                   ...             ...
# 1169618                     9                    21      California
# 1169619                     9                    21      California
# 1169620                     9                    21        Virginia
# 1169621                     9                    21  North Carolina
# 1169622                     9                    21      Washington
#
#          user_nbr_ratings  nbr_ratings climate climate_scheme  \
# 0                  2326.0          137     Cfa      Temperate
# 1                  3098.0          137     Cfa      Temperate
# 2                  1866.0          137     Cfa      Temperate
# 3                  1131.0          137     Cfa      Temperate
# 4                  9987.0          137     Cfa      Temperate
# ...                   ...          ...     ...            ...
# 1169618            8218.0           11     Csa      Temperate
# 1169619           12041.0           11     Csa      Temperate
# 1169620            3337.0           11     Cfa      Temperate
# 1169621           22799.0           11     Cfa      Temperate
# 1169622            1124.0           11     Dsb    Continental
#
#         climate_precipitation climate_temperature
# 0          without dry season          hot summer
# 1          without dry season          hot summer
# 2          without dry season          hot summer
# 3          without dry season          hot summer
# 4          without dry season          hot summer
# ...                       ...                 ...
# 1169618       with dry season          hot summer
# 1169619       with dry season          hot summer
# 1169620    without dry season          hot summer
# 1169621    without dry season          hot summer
# 1169622       with dry season         warm summer
#
# [1169623 rows x 35 columns]
